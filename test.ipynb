# %%
import ta

# %%
help(ta)
# Out:
# Help on package ta:
#
# NAME
#     ta
#
# DESCRIPTION
#     It is a Technical Analysis library useful to do feature
#     engineering from financial time series datasets (Open,
#     Close, High, Low, Volume). It is built on Pandas and Numpy.
#
#     .. moduleauthor:: Dario Lopez Padial (Bukosabino)
#
# PACKAGE CONTENTS
#     momentum
#     others
#     trend
#     utils
#     volatility
#     volume
#     wrapper
#
# FUNCTIONS
#     add_all_ta_features(df: pandas.core.frame.DataFrame, open: str, high: str, low: str, close: str, volume: str, fillna: bool = False, colprefix: str = '', vectorized: bool = False) -> pandas.core.frame.DataFrame
#         Add all technical analysis features to dataframe.
#
#         Args:
#             df (pandas.core.frame.DataFrame): Dataframe base.
#             open (str): Name of 'open' column.
#             high (str): Name of 'high' column.
#             low (str): Name of 'low' column.
#             close (str): Name of 'close' column.
# ...
